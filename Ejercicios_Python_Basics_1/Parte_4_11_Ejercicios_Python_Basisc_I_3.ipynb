# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 3:
# ## Operaciones matemáticas, comparación y booleanas

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
#
# ## Ejercicio 1
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print(A == B)
print(A != C)
print(A > C)
print(C <= A)
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
valor_1 = input("Introduce el primer valor: ")
valor_2 = input("Introduce el segundo valor: ")

print(valor_1 == valor_2)
# Out:
# Introduce el primer valor:  4
# Introduce el segundo valor:  4
# True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Mismo programa que en 2, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
a = input("Introduce el primer valor: ")
b = input("Introduce el segundo valor: ")
c = input("Introduce el tercer valor: ")

print(a == b == c)
print(a == b or a == c or b == c)
# Out:
# Introduce el primer valor:  4
# Introduce el segundo valor:  5
# Introduce el tercer valor:  4
# False
# True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %%
# 1. La operación and solo da True si todos son True.
# Resultado: False

# 2. Primero miramos dentro de los paréntesis. Cada parte de True or False da True (con or basta con que uno deellos sea verdadero)
# En los paréntesis hay True and True que resulta True. Luego hay un not True, que se convierte en False.
# Resultado: False

# 3. En or, aunque haya varios False, con que haya un solo True, todo el or se convierte en True.
# Después tenemos True and False. En un and con que hayaun solo False, todo se convierte en False.
# Resultado: False

# 4. not False se convierte en True y not True se convierte en False.
# Si sustituimos la expresión queda como True and True and False.
# En una cadena de and, si aparece un False, todo se vuelve False.
# Resultado: False
